# %% [markdown]
# # Nguồn:
# https://pytorch.org/tutorials/beginner/basics/data_tutorial.html
#
# # Nội dung chính
# 1. Loading a Dataset
# 2. Iterating and Visualizing the Dataset
# 3. Creating a Custom Dataset for your files
# 4. Preparing your data for training with DataLoaders

# %% [markdown]
# Code để xử lý các mẫu dữ liệu có thể lộn xộn và khó bảo trì; Pytorch cung cấp 2 class chính giúp chúng ta trong việc pre-loader dataset là: **torch.utils.data.Dataset** và **torch.utils.data.Dataloader**.
#
# **Dataset** lưu trữ các mẫu và label tương ứng, và **Dataloader** tạo iterator quanh Dataset để dễ dàng truy xuất vào các mẫu dữ liệu.
#
# Thư viện miền PyTorch cung cấp một số bộ dữ liệu được tải sẵn (chẳng hạn như FashionMNIST) phân lớp torch.utils.data.Dataset và triển khai các chức năng dành riêng cho dữ liệu cụ thể.  Chúng có thể được sử dụng để tạo mẫu và chuẩn mô hình của bạn. Bạn có thể tìm thấy chúng tại: <a href="https://pytorch.org/docs/stable/torchvision/datasets.html">Image Datasets</a>, <a href="https://pytorch.org/text/stable/datasets.html">Text Datasets</a>, <a href="https://pytorch.org/audio/stable/datasets.html">Audio Datasets</a>

# %% [markdown]
# # 1. Loading a Dataset
# Ở phần này, chúng ta sẽ tìm hiểu làm thế nào để load bộ dữ liệu Fashion-MNIST từ **TorchVision**. Fashion-MNIST là một bộ dữ liệu của Zalado bao gồm 60000 mẫu training và 10000 mẫu testing. Với mỗi mẫu là một ảnh xám 28x28 và có 10 nhãn.
#
# Chúng ta load bộ dữ liệu FashionMNIST với các tham số sau:
# * *root* là đường dẫn để lưu trữ dữ liệu train/test
# * *train* chỉ định tập dữ liệu train hoặc test
# * *download=True* Tải dữ liệu từ internet nếu nó không khả dụng tại *root*
# * *transform* và *target_transform* chuyển đổi các đặc trưng và nhaxn

# %%
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda
import matplotlib.pyplot as plt

training_data = datasets.FashionMNIST(
    root="./data",
    train=True,
    download=True,
    transform=ToTensor()
)

test_data = datasets.FashionMNIST(
    root="./data",
    train=False,
    download=True,
    transform=ToTensor()
)

# %% [markdown]
# # 2. Iterating and Visualizing the Dataset
# Chúng ta có thể index **Datasets** như một list: **training_data[index]**. Chúng ta sử dụng **matplotlib** để mô phỏng một số mẫu trong tập training.

# %%
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}

figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()
    img, label = training_data[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %% [markdown]
# # 3. Creating a Custom Dataset for your files
# Một class Dataset mà chúng ta custom phải thực thi 3 hàm: **__init__**, **__len__**, **__getitem__**. Hãy xem cách triển khai này;  hình ảnh FashionMNIST được lưu trữ trong thư mục **img_dir** và nhãn của chúng được lưu trữ riêng trong tệp CSV **annotations_file**.

# %%
import os
import pandas as pd
from PIL import Image

class CustomDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None, target_transform=None):
        self.img_labels = pd.read_csv(annotations_file)
        self.img_dir = img_dir
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
        image = Image.open(img_path)
        label = self.img_labels.iloc[idx, 1]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        sample = {"image": image, "label": label}
        return sample

# %% [markdown]
# Hàm __init__ được chạy một lần khi khởi tạo đối tượng Dataset.  Chúng tôi khởi tạo thư mục chứa hình ảnh, tệp chú thích và cả hai phép biến đổi (được trình bày chi tiết hơn trong phần tiếp theo).
#
# Tệp label.csv trông giống như sau:
# >tshirt1.jpg, 0 <br/>
# tshirt2.jpg, 0  <br/>
# ...... <br/>
# ankleboot999.jpg, 9 <br/>
#
#
# Hàm __len__ trả về số lượng mẫu trong tập dữ liệu của chúng tôi.
#
# Hàm __getitem__ tải và trả về một mẫu từ tập dữ liệu tại idx chỉ mục đã cho.  Dựa trên chỉ mục, nó xác định vị trí của hình ảnh trên đĩa, chuyển đổi vị trí đó thành tensor bằng cách sử dụng read_image, truy xuất nhãn tương ứng từ dữ liệu csv trong self.img_labels, gọi các hàm biến đổi trên chúng (nếu có) và trả về hình ảnh tensor  và nhãn tương ứng trong một câu lệnh Python.

# %% [markdown]
# # 4. Preparing your data for training with DataLoaders
#
# **Dataset** truy xuất các đặc trưng của tập dữ liệu của chúng tôi và gắn nhãn từng mẫu một. Trong khi huấn luyện mô hình, chúng ta muốn pass các mẫu dữ liệu trong một minibatch, xáo trộn dữ liệu tại mỗi epoch để giảm overfitting, và sử dụng **multiprocessing** để tăng tốc độ.
#
# **Dataloader** là một iterable hỗ trợ các công việc phức tạp này trở nên dễ dàng.

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(training_data, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=64, shuffle=True)

# %% [markdown]
# Chúng ta có thể load các dataset từ **Dataloader** và có thể iterate qua dataset. Mỗi vòng lặp dưới đây trả về một batch của **train_features** và **train_labels** (64)

# %%
train_features, train_labels = next(iter(train_dataloader))
print("Features shape:", train_features.size())
print("Labels shape:", train_labels.size())

img = train_features[0].squeeze()
label = train_labels[0]

plt.imshow(img, cmap='gray')
plt.show()
print(label)
# Out:
# Features shape: torch.Size([64, 1, 28, 28])
# Labels shape: torch.Size([64])
# tensor(0)

# %% [markdown]
# Về cơ bản, tới bài này chúng ta đã có thể có các khái niệm để thực hiện một project Deep learning bằng Pytorch, các bạn có thể xem mẫu về 1 project đơn giản bằng pytorch tại github sau: https://github.com/nducthang/BERT-Tweet-Sentiment-Kaggle
#
# Trong này tôi đã thực hiện load dataset, xây dựng mô hình và chạy mô hình với Pytorch.
